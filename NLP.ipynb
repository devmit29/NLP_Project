# %% [markdown]
# <a href="https://colab.research.google.com/github/devmit29/NLP_Project/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####Importing Libraries

# %%
import nltk
from nltk.corpus import stopwords
import string
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# #### Reading Novel and converting it into a text variable

# %%
variable_name = ""
file = open("./gdrive/MyDrive/The_Formula_for_Murder.txt",encoding='utf-8')
wordslist = file.read().splitlines() # to escape \n occurence
wordslist = [i for i in wordslist if i!='']
text = ""
text = text.join(wordslist)
type(file)
# Out:
# _io.TextIOWrapper

# %%
text[:1500] #first 1500 characters of out Novel T
# Out:
# 'The author and publisher have provided this e-book to you without DigitalRights Management software (DRM) applied so that you can enjoy readingit on your personal devices. This e-book is for your personal use only. Youmay not print or post this e-book, or make this e-book publicly available inany way. You may not copy, reproduce or upload this e-book, other than toread it on one of your personal devices.Copyright infringement is against the law. If you believe the copy ofthis e-book you are reading infringes on the author’s copyright, pleasenotify the publisher at: us.macmillanusa.com/piracy.                   GENEVIEVE J. FOXEY MCCLEARYA strong woman who has the courage to change and a heart of gold, My                             sister …                           ACKNOWLEDGMENTSSometimes we have an opportunity in life and don’t see it until later downthe road. I have been given a very wonderful opportunity to write aboutNellie Bly, and for this I shall always be grateful to Linda
# ...

# %%
len(text)
# Out:
# 542832

# %% [markdown]
# ####Preprocessing

# %%
#Creating a string which has all the punctuations to be removed
punctuations = '''!()-[]{};:'"\,<>./‘’?“”@#$%^&*_~'''
cleantext = ""
for char in text:
    if char not in punctuations:
        cleantext = cleantext + char

#Converting the text into lower case
cleantext = cleantext.lower()

# %%
cleantext
# Out:
# 'the author and publisher have provided this ebook to you without digitalrights management software drm applied so that you can enjoy readingit on your personal devices this ebook is for your personal use only youmay not print or post this ebook or make this ebook publicly available inany way you may not copy reproduce or upload this ebook other than toread it on one of your personal devicescopyright infringement is against the law if you believe the copy ofthis ebook you are reading infringes on the authors copyright pleasenotify the publisher at usmacmillanusacompiracy                   genevieve j foxey mcclearya strong woman who has the courage to change and a heart of gold my                             sister …                           acknowledgmentssometimes we have an opportunity in life and dont see it until later downthe road i have been given a very wonderful opportunity to write aboutnellie bly and for this i shall always be grateful to linda quinton bobgleason tom dohe
# ...

# %% [markdown]
# ####Tokens

# %%
tokens = word_tokenize(cleantext)
tokens
# Out:
# ['the',
#  'author',
#  'and',
#  'publisher',
#  'have',
#  'provided',
#  'this',
#  'ebook',
#  'to',
#  'you',
#  'without',
#  'digitalrights',
#  'management',
#  'software',
#  'drm',
#  'applied',
#  'so',
#  'that',
#  'you',
#  'can',
#  'enjoy',
#  'readingit',
#  'on',
#  'your',
#  'personal',
#  'devices',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'your',
#  'personal',
#  'use',
#  'only',
#  'youmay',
#  'not',
#  'print',
#  'or',
#  'post',
#  'this',
#  'ebook',
#  'or',
#  'make',
#  'this',
#  'ebook',
#  'publicly',
#  'available',
#  'inany',
#  'way',
#  'you',
#  'may',
#  'not',
#  'copy',
#  'reproduce',
#  'or',
#  'upload',
#  'this',
#  'ebook',
#  'other',
#  'than',
#  'toread',
#  'it',
#  'on',
#  'one',
#  'of',
#  'your',
#  'personal',
#  'devicescopyright',
#  'infringement',
#  'is',
#  'against',
#  'the',
#  'law',
#  'if',
#  'you',
#  'believe',
#  'the',
#  'copy',
#  'ofthis',
#  'ebook',
#  'you',
#  'are',
#  'reading',
# ...

# %%
type(tokens)
# Out:
# list

# %%
len(tokens)
# Out:
# 92132

# %% [markdown]
# ####Tokenization and Removing stopwords

# %%
# Removing stopwords and storing it into finaltext
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(cleantext)
tokens_final = [i for i in tokens if not i in stop_words] # tokenising with removing stopwords
finaltext = "  "
finaltext = finaltext.join(tokens_final)

# %%
finaltext
# Out:
# 'author  publisher  provided  ebook  without  digitalrights  management  software  drm  applied  enjoy  readingit  personal  devices  ebook  personal  use  youmay  print  post  ebook  make  ebook  publicly  available  inany  way  may  copy  reproduce  upload  ebook  toread  one  personal  devicescopyright  infringement  law  believe  copy  ofthis  ebook  reading  infringes  authors  copyright  pleasenotify  publisher  usmacmillanusacompiracy  genevieve  j  foxey  mcclearya  strong  woman  courage  change  heart  gold  sister  …  acknowledgmentssometimes  opportunity  life  dont  see  later  downthe  road  given  wonderful  opportunity  write  aboutnellie  bly  shall  always  grateful  linda  quinton  bobgleason  tom  doherty  harvey  klinger  would  also  like  extend  thanks  katharine  critchlow  anincredible  young  lady  helpful  formula  murderand  whitney  ross  constantly  coming  everyones  rescue  thankyou  whitney  wish  names  people  productiondepartment  every  one  done
# ...

# %% [markdown]
# ####Frequency Distribution of Tokens

# %%
#Frequency Distribution of Tokens without stopwords
freq = nltk.FreqDist(tokens_final)
freq = {k: v for k, v in sorted(freq.items(), key=lambda item: item[1],reverse=True)}
x = list(freq.keys())[:40]
y = list(freq.values())[:40]
plt.figure(figsize=(12,5))
plt.plot(x,y,c='r',lw=4,ls='-.')
plt.grid()
plt.xticks(rotation=90)
plt.title('Token Frequency (without stopwords)',size=17)
plt.xlabel('Words',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %% [markdown]
# ####Word Cloud after removing Stopwords

# %%
#Word Cloud after removing Stopwords
wordcloud = WordCloud(width = 700, height = 400,
                background_color ='black',
                min_font_size = 10,stopwords = {},colormap='summer').generate(finaltext)

plt.figure(figsize = (6,10), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# ####PoS Tagging and Frequency Distribution of Tags on Text

# %%
tagged = nltk.pos_tag(tokens)
tagged[:20] #first 20 POS tage
# Out:
# [('the', 'DT'),
#  ('author', 'NN'),
#  ('and', 'CC'),
#  ('publisher', 'NN'),
#  ('have', 'VBP'),
#  ('provided', 'VBN'),
#  ('this', 'DT'),
#  ('ebook', 'NN'),
#  ('to', 'TO'),
#  ('you', 'PRP'),
#  ('without', 'IN'),
#  ('digitalrights', 'NNS'),
#  ('management', 'NN'),
#  ('software', 'NN'),
#  ('drm', 'NN'),
#  ('applied', 'VBD'),
#  ('so', 'RB'),
#  ('that', 'IN'),
#  ('you', 'PRP'),
#  ('can', 'MD')]

# %%
type(tagged)
# Out:
# list

# %%
from collections import Counter
counts = Counter( tag for word,  tag in tagged)
print(counts)
# Out:
# Counter({'NN': 18536, 'IN': 10692, 'DT': 8772, 'JJ': 7168, 'PRP': 5596, 'NNS': 4634, 'RB': 4577, 'VB': 4186, 'VBP': 4028, 'VBZ': 3444, 'VBD': 3171, 'CC': 3019, 'PRP$': 2717, 'TO': 2538, 'VBG': 2215, 'VBN': 1938, 'MD': 1019, 'RP': 699, 'WP': 614, 'CD': 607, 'WRB': 603, 'WDT': 462, 'JJR': 249, 'EX': 169, 'JJS': 132, 'RBR': 127, 'PDT': 79, 'RBS': 55, 'NNP': 31, 'FW': 30, 'UH': 15, 'WP$': 10})

# %%
freq_tags = nltk.FreqDist(counts)
freq_tags = {k: v for k, v in sorted(freq_tags.items(), key=lambda item: item[1],reverse=True)}
x = list(freq_tags.keys())[:40]
y = list(freq_tags.values())[:40]
plt.figure(figsize=(12,5))
plt.plot(x,y,c='r',lw=4,ls='-.')
plt.grid()
plt.xticks(rotation=90)
plt.title('TAGs Frequency',size=17)
plt.xlabel('Tags',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %% [markdown]
# ####Bigram Probability

# %%
files = open("./gdrive/MyDrive/Largest_chapter_2.txt",encoding='latin-1')
wordslists = files.read().splitlines() # to escape \n occurence
wordslists = [i for i in wordslists if i!='']
w= ""
w = w.join(wordslists)

# %%
words=w.split()
bigrams = [(words[i], words[i + 1]) for i in range(len(words) - 1)]
from collections import Counter

bigram_counts = Counter(bigrams)
bigram_probabilities = {}
for bigram, count in bigram_counts.items():
    word1, word2 = bigram
    bigram_probabilities[bigram] = count / words.count(word1)

from tabulate import tabulate
table_data = []
for bigram, probability in bigram_probabilities.items():
    word1, word2 = bigram
    table_data.append([word1, word2, probability])


headers = ['Word 1', 'Word 2', 'Probability']


print(tabulate(table_data, headers=headers, tablefmt='grid'))
# Out:
# +---------------------+---------------------+---------------+
# | Word 1              | Word 2              |   Probability |
# +=====================+=====================+===============+
# | I                   | shiver              |    0.0285714  |
# +---------------------+---------------------+---------------+
# | shiver              | as                  |    1          |
# +---------------------+---------------------+---------------+
# | as                  | I                   |    0.307692   |
# +---------------------+---------------------+---------------+
# | I                   | leave               |    0.0285714  |
# +---------------------+---------------------+---------------+
# | leave               | a                   |    1          |
# +---------------------+---------------------+---------------+
# | a                   | gloomy              |    0.015873   |
# +---------------------+---------------------+---------------+
# ...

# %% [markdown]
# ####Shanon Game

# %%
def make_guess(previous_word, bigram_probabilities):
    next_word_probabilities = {word: prob for (prev, word),prob in bigram_probabilities.items() if prev == previous_word}
    sorted_guesses = sorted(next_word_probabilities, key=next_word_probabilities.get, reverse=True)
    return sorted_guesses

# %%
# Implement the Shannon Game using the pre-calculated bigram probabilities
def play_shannon_game(existing_string, bigram_probabilities):
    s=''
    print("Welcome to Shannon's Game:")
    print("Give me a wqord, I will try to guess it based on provided string.")
    print("Please respond with 'yes' or 'no' to my guess.")
    print("You can end the game by typing 'exit'.")

    previous_word=input("Thinking of a starting word")
    print(f"Starting word: {previous_word}")
    s=s+" "+previous_word

    while True:
      guesses = make_guess(previous_word, bigram_probabilities)
      for guess in guesses:
        response = input(f"Is it '{guess}'? (yes/no): ")
        if response == 'yes':
          previous_word = guess
          s=s+" "+guess
          print(f"Sentence: {s}")
          break
        elif response == 'exit':
            print("Thanks for Playing")
            return
        else:
          previous_word = guess

        #   print("No more guesses. Thanks")

# %%
other_chapter = open("./gdrive/MyDrive/Other_Chapter.txt")

# %%
# if other_chapter != -1:
#   next_chapter = text.find("other_chapter + 1  ")
#   if next_chapter == -1:
#       next_chapter = text.find("THE END", other_chapter +1)
#       other_chapter_text = text[other_chapter:next_chapter]
#       other_chapter_cleaned = other_chapter_text.replace('\xDc', '')
# else:
#     print("Chapter Two not found in the test.")

# %% [markdown]
# Creating a string

# %%
# other_chapter_cleaned_2 = other_chapter_cleaned[22:]
# other_chapter_cleaned_2[:2000]

# %%
play_shannon_game(other_chapter, bigram_probabilities)
# Out:
# Welcome to Shannon's Game:
# Give me a wqord, I will try to guess it based on provided string.
# Please respond with 'yes' or 'no' to my guess.
# You can end the game by typing 'exit'.
# Thinking of a starting wordThis
# Starting word: This
# Is it 'small'? (yes/no): no
# Is it 'branch'? (yes/no): yes
# Sentence:  This branch
# Is it 'of'? (yes/no): yes
# Sentence:  This branch of
# Is it 'the'? (yes/no): yes
# Sentence:  This branch of the
# Is it 'bodies'? (yes/no): no
# Is it 'dead'? (yes/no): no
# Is it 'river'? (yes/no): yes
# Sentence:  This branch of the river
# Is it 'and'? (yes/no): no
# Is it 'stinks'? (yes/no): yes
# Sentence:  This branch of the river stinks
# Is it 'worse'? (yes/no): exit
# Thanks for Playing
